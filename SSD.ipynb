# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd './drive/MyDrive/SSD'
# Out:
# /content/drive/MyDrive/SSD

# %%
# !python prepare_data.py

# %%
#download vgg weights as initializer
# %cd './data'
# %mkdir 'weights'
# Out:
# /content/drive/MyDrive/SSD/data

# %%
# %cd './weights'
# !wget https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth
# Out:
# /content/drive/MyDrive/SSD/data/weights
# --2023-10-05 06:33:36--  https://s3.amazonaws.com/amdegroot-models/vgg16_reducedfc.pth
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.124.72, 54.231.230.104, 52.217.19.6, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81938914 (78M) [binary/octet-stream]
# Saving to: ‘vgg16_reducedfc.pth’
#
# vgg16_reducedfc.pth 100%[===================>]  78.14M  34.6MB/s    in 2.3s
#
# 2023-10-05 06:33:38 (34.6 MB/s) - ‘vgg16_reducedfc.pth’ saved [81938914/81938914]

# %%
# %cd ../..
# Out:
# /content/drive/MyDrive/SSD

# %%
# !python train.py
# Out:
# ------------------------------------------------------------
# Epoch 1/30
# ------------------------------------------------------------
# (Training)
# Iteration 10 || Loss: 14.4429 || 10iter: 50.8916 sec
# Iteration 20 || Loss: 11.1406 || 10iter: 16.7089 sec
# Iteration 30 || Loss: 9.9383 || 10iter: 17.3793 sec
# Iteration 40 || Loss: 8.4606 || 10iter: 22.3876 sec
# Iteration 50 || Loss: 8.0452 || 10iter: 16.8188 sec
# Iteration 60 || Loss: 7.6627 || 10iter: 16.6263 sec
# Iteration 70 || Loss: 8.6302 || 10iter: 17.3615 sec
# Iteration 80 || Loss: 7.8136 || 10iter: 17.3254 sec
# Iteration 90 || Loss: 8.6345 || 10iter: 16.4497 sec
# Iteration 100 || Loss: 7.8411 || 10iter: 16.5127 sec
# Iteration 110 || Loss: 7.1227 || 10iter: 17.6487 sec
# Iteration 120 || Loss: 8.2149 || 10iter: 17.3979 sec
# Iteration 130 || Loss: 7.6143 || 10iter: 17.2443 sec
# Iteration 140 || Loss: 8.6586 || 10iter: 17.0159 sec
# Iteration 150 || Loss: 7.5028 || 10iter: 17.2700 sec
# ...
